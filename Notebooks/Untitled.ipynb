# %% [markdown]
# Snakes

# %%
import pandas as pd
import re

trash_df = pd.read_csv('../data/trash_hauler_report.csv')
#Explore the data
print(trash_df.shape)
print(trash_df.columns)
print(trash_df.dtypes)
print(trash_df.info())
trash_df.head()
# Out:
# (20226, 11)
# Index(['Request Number', 'Date Opened', 'Request ', 'Description',
#        'Incident Address', 'Zip Code', 'Trash Hauler', 'Trash Route',
#        'Council District', 'State Plan X', 'State Plan Y'],
#       dtype='object')
# Request Number        int64
# Date Opened          object
# Request              object
# Description          object
# Incident Address     object
# Zip Code            float64
# Trash Hauler         object
# Trash Route          object
# Council District    float64
# State Plan X        float64
# State Plan Y        float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20226 non-null  int64
#  1   Date Opened       20226 non-null  object
#  2   Request           20226 non-null  object
#  3   Description       20195 non-null  object
# ...

# %%
import pandas as pd
cleaned_missed_pickups = pd.read_csv('../data/cleaned_missed_pickups.csv')
print(cleaned_missed_pickups.shape)
print(cleaned_missed_pickups.columns)
print(cleaned_missed_pickups.dtypes)
print(cleaned_missed_pickups.info())
cleaned_missed_pickups.head()
# Out:
# (17583, 13)
# Index(['Request Number', 'Date Opened', 'Request', 'Description',
#        'Incident Address', 'Zip Code', 'Trash Hauler', 'Trash Route',
#        'Council District', 'State Plan X', 'State Plan Y', 'description_clean',
#        'Street Name'],
#       dtype='object')
# Request Number         int64
# Date Opened           object
# Request               object
# Description           object
# Incident Address      object
# Zip Code             float64
# Trash Hauler          object
# Trash Route           object
# Council District     float64
# State Plan X         float64
# State Plan Y         float64
# description_clean     object
# Street Name           object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17583 entries, 0 to 17582
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request Number     17583 non-null  int64
# ...

# %%
fee_per_missed_pickup=200

# %%
missed_counts=cleaned_missed_pickups['Description'].str.contains('missed' ,case=False ,na=False)

# %%
print(missed_counts)
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 17578     True
# 17579     True
# 17580    False
# 17581     True
# 17582     True
# Name: Description, Length: 17583, dtype: bool

# %%
print(missed_counts.head())
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Description, dtype: bool

# %%
print(missed_counts.head())
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Description, dtype: bool

# %% [markdown]
# merge_try=pd.merge(missed_counts,cleaned_missed_pickups., on 'adress', how 'left')

# %%
merge_try = pd.merge(
    missed_counts, 
    cleaned_missed_pickups, 
    left_index=True, 
    right_index=True, 
    how='left'
)

# %%
print(merge_try.head(5))
# Out:
#    Description_x  Request Number Date Opened  \
# 0          False           25274  2017-11-01
# 1          False           25276  2017-11-01
# 2           True           25307  2017-11-01
# 3           True           25312  2017-11-01
# 4          False           25327  2017-11-01
#
#                                 Request  \
# 0  Trash - Curbside/Alley Missed Pickup
# 1  Trash - Curbside/Alley Missed Pickup
# 2  Trash - Curbside/Alley Missed Pickup
# 3  Trash - Curbside/Alley Missed Pickup
# 4            Trash Collection Complaint
#
#                                   Description_y       Incident Address  \
# 0                      Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 1                      Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 2                                        missed   2603 old matthews rd
# 3             Missed the even side of the road.          604 croley dr
# 4  Trash out on time, miss again Tuesday. ALLEY   1816 Jo Johnston Ave
#
# ...

# %%
merge_try.columns
# Out:
# Index(['Description_x', 'Request Number', 'Date Opened', 'Request',
#        'Description_y', 'Incident Address', 'Zip Code', 'Trash Hauler',
#        'Trash Route', 'Council District', 'State Plan X', 'State Plan Y',
#        'description_clean', 'Street Name'],
#       dtype='object')

# %%
merge_try['missed']= merge_try[merge_try['Description_x'].strcontains('missed', case=False,n
